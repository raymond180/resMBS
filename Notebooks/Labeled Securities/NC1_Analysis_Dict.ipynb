# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %% [markdown]
# This notebook shows some basics stats about securities labeled as NC1

# %% [markdown]
# ## Load Data

# %%
df_dict = {}
for n in range(2,9):
    file_name = 'trimmed_'+ str(2000+n) +'_v2.csv'
    data = pd.read_csv(file_name)
    df_dict[str(2000+n)] = data

# %%
df_dict.keys()
# Out:
# dict_keys(['2002', '2003', '2004', '2005', '2006', '2007', '2008'])

# %%
for year in df_dict:
    print(year)
# Out:
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008

# %%
#Get all rows with NC1
nc1 = {}
for year in df_dict:
    nc1[year] = df_dict[year].loc[df_dict[year]['Label'] == 'NC1(failing)']

# %% [markdown]
# ## Data Validation

# %%
print('we have {} rows of data'.format(data.shape[0]))
print('we have {} rows of NC1'.format(nc1.shape[0]))
print('percentage: {:.2f}%'.format(nc1.shape[0]/data.shape[0]*100))
# Out:
# we have 4450 rows of data
# we have 461 rows of NC1
# percentage: 10.36%

# %%
#groupby label and check # unique value
print('List of all labels count:')
data.groupby('Label')['CUSIP'].nunique()
# Out:
# List of all labels count:
# Label
# 0                                41
# 1.4                             133
# FE                              397
# IOfailing                         1
# IOpassMED                       114
# IOpassMEY                        79
# MED                            1220
# MEY                            1251
# NC1(failing)                    461
# NC2(z>1 nsf)                     24
# NC3(z>1, not paid off, nsf)      24
# NMEm                            638
# NMEs                              7
# Name: CUSIP, dtype: int64

# %%
valid = data.groupby('Label')['CUSIP'].nunique()['NC1(failing)'] == nc1.shape[0]
print('Does row of nc1 equals # of nc1 in the data? {}'.format(valid))
# Out:
# Does row of nc1 equals # of nc1 in the data? True

# %% [markdown]
# ## Explore NC1

# %%
count = nc1.groupby('Prospectus')['CUSIP'].nunique().count()
print('There are ' + str(count) + ' of prospectus that have NC1')
print("On average {:.2f} NC1 per prospectus that have NC1".format(nc1.shape[0]/count))
# Out:
# There are 150 of prospectus that have NC1
# On average 3.07 NC1 per prospectus that have NC1

# %%
show_top = 5
print('Top {} of the MTG_TRANCHE_TYP_LONG among NC1 are:'.format(show_top))
nc1.groupby('MTG_TRANCHE_TYP_LONG')['CUSIP'].nunique().sort_values(ascending=False).head(show_top)
# Out:
# Top 5 of the MTG_TRANCHE_TYP_LONG among NC1 are:
# MTG_TRANCHE_TYP_LONG
# SUB,CSTR,NAS    281
# SUB,NAS         126
# MEZ,FLT,STEP     10
# SUB,CSTR,AS       7
# SUB,CSTR          4
# Name: CUSIP, dtype: int64

# %%
valid = (data.loc[data['Label'] != 'NC1(failing)'].shape[0]) == data.shape[0]-nc1.shape[0]
print("Is [data['Label'] != 'NC1(failing)'] valid? {}".format(valid))
# Out:
# Is [data['Label'] != 'NC1(failing)'] valid? True

# %%
print('Top {} of the MTG_TRANCHE_TYP_LONG among non-NC1s are:'.format(show_top))
data.loc[data['Label'] != 'NC1(failing)'].groupby('MTG_TRANCHE_TYP_LONG')['CUSIP'].nunique().sort_values(ascending=False).head(show_top)
# Out:
# Top 5 of the MTG_TRANCHE_TYP_LONG among non-NC1s are:
# MTG_TRANCHE_TYP_LONG
# SUB,CSTR,NAS        441
# SEQ,AS              262
# SUB,NAS             238
# MEZ,FLT,STEP,IRC    227
# CSTR,PT,AS          189
# Name: CUSIP, dtype: int64

# %% [markdown]
# In 2004, MTG_TRANCHE_TYP_LONG among NC1 and non-NC1 data set, SUB (Subordinated), CSTR(Collateral Strip Rate), and NAS(Non-Accelerated Security) seems to be the top components. <br>
#
# In 2005, MTG_TRANCHE_TYP_LONG among NC1 and non-NC1 data set, FLT(Floater), STEP(Stepped Rate Bond), and MEZ(Mezzanine) seems to be the top components. <br>
#
# For NC1 in 2004, I couldn't really see big difference between both groups.<br>
# For NC1 in 2005, there is really big difference between both groups.<br>
#
# [See here for more info about MTG_TRANCHE_TYP](https://docs.google.com/spreadsheets/d/1MOwPnTr2owqPoJNy73U7UEc3z1RvtzELOCM0ZFxBJU8/edit?usp=sharing)

# %%
total = nc1['MTG ORIG AMT'].sum()
print('Sum of MTG ORIG AMT among NC1 = {:.2f}'.format(total))
# Out:
# Sum of MTG ORIG AMT among NC1 = 2113.59

# %%
print('Desciption of MTG ORIG AMT among NC1:')
nc1['MTG ORIG AMT'].describe()
# Out:
# Desciption of MTG ORIG AMT among NC1:
# count    461.000000
# mean       4.584784
# std       29.141494
# min        0.048000
# 25%        0.644000
# 50%        1.200900
# 75%        2.273000
# max      560.470000
# Name: MTG ORIG AMT, dtype: float64

# %% [markdown]
# ## To do
# - Look into Bloomberg (Paydown Infomation?)
# - Look why payment just suddenly stops instead of gradually decreased and stoped
# - Why is CUSIP duplicated?

# %% [markdown]
# ## Why is CUSIP duplicated?
# The folling shows that there are duplicate CUSIP in the data set

# %%
data.groupby('Label')['CUSIP'].count()
# Out:
# Label
# 0                                41
# 1.4                             136
# FE                              400
# IOfailing                         1
# IOpassMED                       114
# IOpassMEY                        81
# MED                            1232
# MEY                            1285
# NC1(failing)                    461
# NC2(z>1 nsf)                     24
# NC3(z>1, not paid off, nsf)      24
# NMEm                            644
# NMEs                              7
# Name: CUSIP, dtype: int64

# %%
data.groupby('Label')['CUSIP'].nunique()
# Out:
# Label
# 0                                41
# 1.4                             133
# FE                              397
# IOfailing                         1
# IOpassMED                       114
# IOpassMEY                        79
# MED                            1220
# MEY                            1251
# NC1(failing)                    461
# NC2(z>1 nsf)                     24
# NC3(z>1, not paid off, nsf)      24
# NMEm                            638
# NMEs                              7
# Name: CUSIP, dtype: int64

# %% [markdown]
# All the Falses show two are in different sizes

# %%
data.groupby('Label')['CUSIP'].count() == data.groupby('Label')['CUSIP'].nunique()
# Out:
# Label
# 0                               True
# 1.4                            False
# FE                             False
# IOfailing                       True
# IOpassMED                       True
# IOpassMEY                      False
# MED                            False
# MEY                            False
# NC1(failing)                    True
# NC2(z>1 nsf)                    True
# NC3(z>1, not paid off, nsf)     True
# NMEm                           False
# NMEs                            True
# Name: CUSIP, dtype: bool

# %% [markdown]
# These are what CUSIPs are duplicated.

# %%
data.groupby(by=['Label','CUSIP']).size().sort_values(ascending=False)
# Out:
# Label      CUSIP
# MEY        126671Y75    3
#            126671Z74    3
# MED        126671Y67    3
#            1266712F2    3
#            1266712B1    3
#            1266712A3    3
# MEY        126671Y83    3
# MED        126671Z90    3
#            126671Z82    3
# 4279  2004   FC_874            MASTR_1302186_0000950136-04-002877.htm    B4
# 4280  2004   FC_874            MASTR_1302186_0000950136-04-002877.htm    B5
# 4281  2004   FC_874            MASTR_1302186_0000950136-04-002877.htm    B6
# 4286  2004   FC_874            MASTR_1302186_0000950136-04-002877.htm   BI5
# 4287  2004   FC_874            MASTR_1302186_0000950136-04-002877.htm   BI6
# 4316  2004   FC_879      WELLS_FARGO_1298039_0001193125-04-122024.htm    B6
# 4332  2004   FC_889      COUNTRYWIDE_1313101_0000950129-04-010175.txt    B2
# 4333  2004   FC_889      COUNTRYWIDE_1313101_0000950129-04-010175.txt    B3
# 4334  2004   FC_889      COUNTRYWIDE_1313101_0000950129-04-010175.txt    B4
# 4335  2004   FC_889      COUNTRYWIDE_1313101_0000950129-04-010175.txt    B5
# 4357  2004   FC_912            MASTR_1292367_0000950136-04-001813.txt    B5
# 4358  2004   FC_912            MASTR_1292367_0000950136-04-001813.txt    B6
# 4414  2004   FC_932     BEAR_STEARNS_1292210_0001068238-04-000838.txt    B3
# 4415  2004   FC_932     BEAR_STEARNS_1292210_0001068238-04-000838.txt    B4
# 4416  2004   FC_932     BEAR_STEARNS_1292210_0001068238-04-000838.txt    B5
# 4417  2004   FC_932     BEAR_STEARNS_1292210_0001068238-04-000838.txt    B6
# 4430  2004   FC_947      WELLS_FARGO_1298676_0001193125-04-125008.htm    B5
# 4431  2004   FC_947      WELLS_FARGO_1298676_0001193125-04-125008.htm    B6
#
#      norm_class                Name  Current_Balance  \
# 79            B   INDX 2004-AR13 B2              0.0
# 80            B   INDX 2004-AR13 B3              0.0
# 81            B   INDX 2004-AR13 B4              0.0
# 82            B   INDX 2004-AR13 B5              0.0
# 83            B   INDX 2004-AR13 B6              0.0
# 156           B      TMST 2004-4 B5              0.0
# 157           B      TMST 2004-4 B6              0.0
# 201           M    MSSTR 2004-1 CB5              0.0
# 202           M    MSSTR 2004-1 CB6              0.0
# 217           B     MSM 2004-7AR B4              0.0
# 248           M     RAMC 2004-4 MF9              0.0
# 261           B      BAFC 2004-D B3              0.0
# 262           B      BAFC 2004-D B4              0.0
# 263           B      BAFC 2004-D B5              0.0
# 264           B      BAFC 2004-D B6              0.0
# 275           B       MSM 2004-9 B4              0.0
# 276           B       MSM 2004-9 B5              0.0
# 277           B       MSM 2004-9 B6              0.0
# 289           B      BAFC 2004-A B5              0.0
# 290           B      BAFC 2004-A B6              0.0
# 310           B     MARM 2004-10 B5              0.0
# 311           B     MARM 2004-10 B6              0.0
# 324           M   SAIL 2004-BNC2 M7              0.0
# 342           B  CWALT 2004-14T2 B3              0.0
# 343           B  CWALT 2004-14T2 B4              0.0
# 344           B  CWALT 2004-14T2 B5              0.0
# 418           B     BSARM 2004-4 B5              0.0
# 419           B     BSARM 2004-4 B6              0.0
# 461           B    BOAA 2004-4 15B3              0.0
# 462           B    BOAA 2004-4 15B4              0.0
# ...         ...                 ...              ...
# 4103          B    MSM 2004-10AR B6              0.0
# 4114          M   RAMP 2004-RS8 MI2              0.0
# 4125          B      SAIL 2004-11 B              0.0
# 4158          B   INDX 2004-AR11 B5              0.0
# 4159          B   INDX 2004-AR11 B6              0.0
# 4166          B     BSARM 2004-6 B3              0.0
# 4167          B     BSARM 2004-6 B4              0.0
# 4168          B     BSARM 2004-6 B5              0.0
# 4169          B     BSARM 2004-6 B6              0.0
# 4197          B      FINA 2004-1 B2              0.0
# 4262          B      CWHL 2004-4 B4              0.0
# 4263          B      CWHL 2004-4 B5              0.0
# 4279          B      MALT 2004-8 B4              0.0
# 4280          B      MALT 2004-8 B5              0.0
# 4281          B      MALT 2004-8 B6              0.0
# 4286          B     MALT 2004-8 BI5              0.0
# 4287          B     MALT 2004-8 BI6              0.0
# 4316          B     WFMBS 2004-O B6              0.0
# 4332          B  CWALT 2004-35T2 B2              0.0
# 4333          B  CWALT 2004-35T2 B3              0.0
# 4334          B  CWALT 2004-35T2 B4              0.0
# 4335          B  CWALT 2004-35T2 B5              0.0
# 4357          B      MALT 2004-5 B5              0.0
# 4358          B      MALT 2004-5 B6              0.0
# 4414          B     BALTA 2004-5 B3              0.0
# 4415          B     BALTA 2004-5 B4              0.0
# 4416          B     BALTA 2004-5 B5              0.0
# 4417          B     BALTA 2004-5 B6              0.0
# 4430          B     WFMBS 2004-M B5              0.0
# 4431          B     WFMBS 2004-M B6              0.0
#
#      Zero-Balance Payment Period Number  Sum Principle Paid  MTG ORIG AMT  \
# 79                                    1              2.0528        5.9600
# 80                                    1              1.1893        3.7250
# 81                                    1              0.9481        2.9800
# 82                                    1              0.5617        1.7900
# 83                                    1              0.3288        1.1906
# 156                                   1              0.5235        1.7000
# 157                                   1              0.8386        3.4034
# 201                                   1              0.0959        0.2940
# 202                                   1              0.1207        0.5879
# 217                                   1              0.7051        3.2380
# 248                                   1              1.1860        4.8000
# 261                                   1              0.4724        2.1170
# 262                                   1              0.2527        1.1550
# 263                                   1              0.1615        0.7700
# 264                                   1              0.3316        1.7322
# 275                                   1              0.2019        1.8530
# 276                                   1              0.1147        1.3470
# 277                                   1              0.1300        0.8430
# 289                                   1              0.3429        0.9180
# 290                                   1              0.1567        0.6132
# 310                                   1              0.5226        1.3050
# 311                                   1              0.3219        0.8301
# 324                                   1              0.8089        5.8720
# 342                                   1              0.1819        1.8000
# 343                                   1              0.0888        1.0000
# 344                                   1              0.0280        0.8000
# 418                                   1              0.9087        2.1080
# 419                                   1              0.3482        1.0547
# 461                                   1              0.1124        0.2760
# 462                                   1              0.0509        0.1380
# ...                                 ...                 ...           ...
# 4103                                  1              0.1743        1.1194
# 4114                                  1              4.5650        9.6250
# 4125                                  1              2.5985        5.7490
# 4158                                  1              0.6667        1.8300
# 4159                                  1              0.4424        1.3324
# 4166                                  1              2.1378        4.4460
# 4167                                  1              1.5770        3.3340
# 4168                                  1              1.0226        2.2230
# 4169                                  1              0.7674        1.8531
# 4197                                  1              1.3741        3.1550
# 4262                                  1              0.2130        0.9000
# 4263                                  1              0.1518        1.2009
# 4279                                  1              0.2040        1.8890
# 4280                                  1              0.0740        1.2590
# 4281                                  1              0.0967        1.0500
# 4286                                  1              0.1083        0.7570
# 4287                                  1              0.0808        0.7585
# 4316                                  1              0.1368        0.7011
# 4332                                  1              0.1287        1.6020
# 4333                                  1              0.0996        1.3350
# 4334                                  1              0.0410        0.9340
# 4335                                  1              0.0205        0.6685
# 4357                                  1              0.2000        1.3230
# 4358                                  1              0.0919        0.9274
# 4414                                  1              4.7369        9.9817
# 4415                                  1              3.1116        6.6545
# 4416                                  1              1.8666        4.1590
# 4417                                  1              0.5197        2.4958
# 4430                                  1              0.5973        1.6010
# 4431                                  1              0.1412        0.8017
#
#        ...        CUSIP MTG_TRANCHE_TYP_LONG Moody Rating  \
# 79     ...    45660N7S8         SUB,CSTR,NAS           WR
# 80     ...    45660N7T6         SUB,CSTR,NAS           WR
# 81     ...    45660N7U3              SUB,NAS          NaN
# 82     ...    45660N7V1              SUB,NAS          NaN
# 83     ...    45660N7W9              SUB,NAS          NaN
# 156    ...    885220GV9         SUB,CSTR,NAS           WR
# 157    ...    885220GX5         SUB,CSTR,NAS           NR
# 201    ...    55265WBX0         SUB,CSTR,NAS          NaN
# 202    ...    55265WBY8         SUB,CSTR,NAS          NaN
# 217    ...    61748HCT6         SUB,CSTR,NAS          NaN
# 248    ...    759950EX2     MEZ,STEP,AFC,NAS           WR
# 261    ...    05946XNJ8         SUB,CSTR,NAS           WR
# 262    ...    05946XNK5         SUB,CSTR,NAS           WR
# 263    ...    05946XNL3         SUB,CSTR,NAS           WR
# 264    ...    05946XNM1         SUB,CSTR,NAS           NR
# 275    ...    61748HGM7         SUB,CSTR,NAS          NaN
# 276    ...    61748HGN5         SUB,CSTR,NAS          NaN
# 277    ...    61748HGP0         SUB,CSTR,NAS          NaN
# 289    ...    06051GBK4         SUB,CSTR,NAS          NaN
# 290    ...    06051GBL2         SUB,CSTR,NAS          NaN
# 310    ...    576433SS6         SUB,CSTR,NAS          NaN
# 311    ...    576433ST4         SUB,CSTR,NAS          NaN
# 324    ...    86358ENQ5     MEZ,FLT,STEP,IRC          NaN
# 342    ...    12667FNT8              SUB,NAS          NaN
# 343    ...    12667FNU5              SUB,NAS          NaN
# 344    ...    12667FNV3              SUB,NAS          NaN
# 418    ...    07384MW24         SUB,CSTR,NAS          NaN
# 419    ...    07384MW32         SUB,CSTR,NAS          NaN
# 461    ...    05948KQG7         SUB,CSTR,NAS          NaN
# 462    ...    05948KQY8         SUB,CSTR,NAS          NaN
# ...    ...          ...                  ...          ...
# 4103   ...    61748HFR7         SUB,CSTR,NAS          NaN
# 4114   ...    76112BAH3     MEZ,STEP,AFC,NAS            C
# 4125   ...    86358EPK6             SUB,STEP           NR
# 4158   ...    45660N7E9         SUB,CSTR,NAS          NaN
# 4159   ...    45660N7G4         SUB,CSTR,NAS          NaN
# 4166   ...    07384MX56         SUB,CSTR,NAS           WR
# 4167   ...    07384MX64         SUB,CSTR,NAS          NaN
# 4168   ...    07384MX72         SUB,CSTR,NAS          NaN
# 4169   ...    07384MX80         SUB,CSTR,NAS          NaN
# 4197   ...    317350AJ5         SUB,STEP,AFC          NaN
# 4262   ...    12669FSQ7              SUB,NAS          NaN
# 4263   ...    12669FSR5              SUB,NAS          NaN
# 4279   ...    576434VH4         SUB,CSTR,NAS          NaN
# 4280   ...    576434VJ0         SUB,CSTR,NAS          NaN
# 4281   ...    576434VK7         SUB,CSTR,NAS          NaN
# 4286   ...    576434VQ4         SUB,CSTR,NAS          NaN
# 4287   ...    576434VR2         SUB,CSTR,NAS          NaN
# 4316   ...    949758AC0         SUB,CSTR,NAS          NaN
# 4332   ...    12667FN43              SUB,NAS          NaN
# 4333   ...    12667FN50              SUB,NAS          NaN
# 4334   ...    12667FN68              SUB,NAS          NaN
# 4335   ...    12667FN76              SUB,NAS          NaN
# 4357   ...    576434SA3         SUB,CSTR,NAS          NaN
# 4358   ...    576434SB1         SUB,CSTR,NAS          NaN
# 4414   ...    07386HJM4         SUB,CSTR,NAS           WR
# 4415   ...    07386HJP7         SUB,CSTR,NAS          NaN
# 4416   ...    07386HJQ5         SUB,CSTR,NAS          NaN
# 4417   ...    07386HJR3         SUB,CSTR,NAS          NaN
# 4430   ...    94979UAQ6         SUB,CSTR,NAS          NaN
# 4431   ...    94979UAR4         SUB,CSTR,NAS          NaN
#
#      Initial Moody Rating Bloomberg Composite HCLB  MTG INT SHRTFLL  \
# 79                     A3                  NR  NaN              NaN
# 80                   Baa3                  NR  NaN              NaN
# 81                    NaN                  NR  NaN              NaN
# 82                    NaN                  NR  NaN              NaN
# 83                    NaN                  NR  NaN              NaN
# 156                    B2                  NR  NaN              NaN
# 157                    NR                  NR  NaN              NaN
# 201                   NaN                  NR  NaN              NaN
# 202                   NaN                  NR  NaN              NaN
# 217                   NaN                  NR  NaN              NaN
# 248                  Baa3                  NR  NaN              NaN
# 261                  Baa2                  NR  NaN              NaN
# 262                   Ba2                  NR  NaN              NaN
# 263                    B2                  NR  NaN              NaN
# 264                    NR                  NR  NaN              NaN
# 275                   NaN                  NR  NaN              NaN
# 276                   NaN                  NR  NaN              NaN
# 277                   NaN                  NR  NaN              NaN
# 289                   NaN                  NR  NaN              NaN
# 290                   NaN                  NR  NaN              NaN
# 310                   NaN                  NR  NaN              NaN
# 311                   NaN                  NR  NaN              NaN
# 324                   NaN                  NR  NaN              NaN
# 342                   NaN                  NR  NaN              NaN
# 343                   NaN                  NR  NaN              NaN
# 344                   NaN                  NR  NaN              NaN
# 418                   NaN                  NR  NaN              NaN
# 419                   NaN                  NR  NaN              NaN
# 461                   NaN                  NR  NaN              NaN
# 462                   NaN                  NR  NaN              NaN
# ...                   ...                 ...  ...              ...
# 4103                  NaN                  NR  NaN              NaN
# 4114                   B1                  NR  0.0              0.0
# 4125                   NR                  NR  NaN              NaN
# 4158                  NaN                  NR  NaN              NaN
# 4159                  NaN                  NR  NaN              NaN
# 4166                 Baa2                  NR  NaN              NaN
# 4167                  NaN                  NR  NaN              NaN
# 4168                  NaN                  NR  NaN              NaN
# 4169                  NaN                  NR  NaN              NaN
# 4197                  NaN                  NR  NaN              NaN
# 4262                  NaN                  NR  NaN              NaN
# 4263                  NaN                  NR  NaN              NaN
# 4279                  NaN                  NR  NaN              NaN
# 4280                  NaN                  NR  NaN              NaN
# 4281                  NaN                  NR  NaN              NaN
# 4286                  NaN                  NR  NaN              NaN
# 4287                  NaN                  NR  NaN              NaN
# 4316                  NaN                  NR  NaN              NaN
# 4332                  NaN                  NR  NaN              NaN
# 4333                  NaN                  NR  NaN              NaN
# 4334                  NaN                  NR  NaN              NaN
# 4335                  NaN                  NR  NaN              NaN
# 4357                  NaN                  NR  NaN              NaN
# 4358                  NaN                  NR  NaN              NaN
# 4414                 Baa2                  NR  NaN              NaN
# 4415                  NaN                  NR  NaN              NaN
# 4416                  NaN                  NR  NaN              NaN
# 4417                  NaN                  NR  NaN              NaN
# 4430                  NaN                  NR  NaN              NaN
# 4431                  NaN                  NR  NaN              NaN
#
#       HIST INTRST SHRTFLL         Label NL_fail
# 79                  0\0\0  NC1(failing)       0
# 80                  0\0\0  NC1(failing)       0
# 81                  0\0\0  NC1(failing)       0
# 82                  0\0\0  NC1(failing)       0
# 83                  0\0\0  NC1(failing)       0
# 156                 0\0\0  NC1(failing)       0
# 157                 0\0\0  NC1(failing)       0
# 201                 0\0\0  NC1(failing)       0
# 202                 0\0\0  NC1(failing)       0
# 217                 0\0\0  NC1(failing)       0
# 248                 0\0\0  NC1(failing)       0
# 261                 0\0\0  NC1(failing)       0
# 262                 0\0\0  NC1(failing)       0
# 263                 0\0\0  NC1(failing)       0
# 264                 0\0\0  NC1(failing)       0
# 275                 0\0\0  NC1(failing)       0
# 276                 0\0\0  NC1(failing)       0
# 277                 0\0\0  NC1(failing)       0
# 289                 0\0\0  NC1(failing)       0
# 290                 0\0\0  NC1(failing)       0
# 310                 0\0\0  NC1(failing)       0
# 311                 0\0\0  NC1(failing)       0
# 324                 0\0\0  NC1(failing)       0
# 342                 0\0\0  NC1(failing)       1
# 343                 0\0\0  NC1(failing)       1
# 344                 0\0\0  NC1(failing)       1
# 418                 0\0\0  NC1(failing)       0
# 419                 0\0\0  NC1(failing)       0
# 461                 0\0\0  NC1(failing)       1
# 462                 0\0\0  NC1(failing)       1
# ...                   ...           ...     ...
# 4103                0\0\0  NC1(failing)       0
# 4114                0\0\0  NC1(failing)       0
# 4125                0\0\0  NC1(failing)       0
# 4158                0\0\0  NC1(failing)       0
# 4159                0\0\0  NC1(failing)       0
# 4166                0\0\0  NC1(failing)       0
# 4167                0\0\0  NC1(failing)       0
# 4168                0\0\0  NC1(failing)       0
# 4169                0\0\0  NC1(failing)       0
# 4197                0\0\0  NC1(failing)       0
# 4262                0\0\0  NC1(failing)       1
# 4263                0\0\0  NC1(failing)       1
# 4279                0\0\0  NC1(failing)       0
# 4280                0\0\0  NC1(failing)       0
# 4281                0\0\0  NC1(failing)       0
# 4286                0\0\0  NC1(failing)       0
# 4287                0\0\0  NC1(failing)       0
# 4316                0\0\0  NC1(failing)       0
# 4332                0\0\0  NC1(failing)       0
# 4333                0\0\0  NC1(failing)       0
# 4334                0\0\0  NC1(failing)       0
# 4335                0\0\0  NC1(failing)       0
# 4357                0\0\0  NC1(failing)       0
# 4358                0\0\0  NC1(failing)       0
# 4414                0\0\0  NC1(failing)       1
# 4415                0\0\0  NC1(failing)       1
# 4416                0\0\0  NC1(failing)       1
# 4417                0\0\0  NC1(failing)       1
# 4430                0\0\0  NC1(failing)       0
# 4431                0\0\0  NC1(failing)       0
#
# [461 rows x 21 columns]
